# %% [markdown]
# # Import libraries

# %%
using Pkg

using Flux, MLDataPattern, Mill, JsonGrinder, JSON, Statistics, IterTools, StatsBase, ThreadTools
using JsonGrinder: suggestextractor, ExtractDict
using Mill: reflectinmodel
using CSV, DataFrames
using Random
using Dates
using Plots
using Printf

# %%
THREADS = Threads.nthreads()
# Out:
# 1

# %% [markdown]
# # Import data

# %%
PATH_BEN_REPORTS = "C:/Users/aleca/PycharmProjects/MasterThesis/dataset1/ben_behavior/"
PATH_MAL_REPORTS = "C:/Users/aleca/PycharmProjects/MasterThesis/dataset1/mal_behavior/"
PATH_TO_LABELS = "C:/Users/aleca/PycharmProjects/MasterThesis/dataset1/labels_behavior.csv" ;

# %%
df=CSV.read(PATH_TO_LABELS,DataFrame);

df_labels_ben=filter("label" => x -> x == 0,df)[1:20,:]
df_labels_mal=filter("label" => x -> x == 1,df)[1:20,:];

df_labels=vcat(df_labels_ben,df_labels_mal)

n_classes=length(Set(df_labels.label));

# %%
@time begin
#labels=[]
jsons = map(df_labels.name,df_labels.label) do n,y
    try 
        if y==1
            path=PATH_MAL_REPORTS
        elseif y==0
            path=PATH_BEN_REPORTS
        end
        x=open(JSON.parse, "$(path)$(n).json")
        #append!(labels,y)
        #x=x
        #delete!(x,"static") # Take only the behavioral info
        #delete!(x,"behavior") # Take only the static info
    catch e
        @error "Error when processing sha $n: $e"
    end
end ;
end
n_samples=length(jsons)
println("N samples: $(n_samples)")
println("N labels: $(n_classes)")
@assert n_samples == length(df_labels.label)
# Out:
# 230.440142 seconds (39.00 M allocations: 3.362 GiB, 1.41% gc time, 0.10% compilation time)
# N samples: 40
# N labels: 2

# %%
typeof(jsons)
# Out:
# Vector{Dict{String, Any}} (alias for Array{Dict{String, Any}, 1})

# %% [markdown]
# # Split train and test, and define the schema

# %%
idx=shuffle(collect(1:n_samples))
tr_frac=0.8
train_indexes=idx[1:round(Int,tr_frac*n_samples)]
test_indexes=setdiff(idx,train_indexes)

train_size = length(train_indexes)
test_size = length(test_indexes)

println("Train size: $(train_size)")
println("Test size: $(test_size)")
# Out:
# Train size: 32
# Test size: 8

# %%
chunks = Iterators.partition(train_indexes, div(train_size, THREADS))
sch_parts = tmap(chunks) do ch
    JsonGrinder.schema(jsons[ch])
end
complete_schema = merge(sch_parts...)
printtree(complete_schema)
# Out:
# ┌ Info: In path [value]: Instability in the schema detected. Using multiple representation.
# └ @ JsonGrinder C:\Users\aleca\.julia\packages\JsonGrinder\HGYbL\src\schema\schema.jl:13
# ┌ Info: In path [iid]: Instability in the schema detected. Using multiple representation.
# └ @ JsonGrinder C:\Users\aleca\.julia\packages\JsonGrinder\HGYbL\src\schema\schema.jl:13
# ┌ Info: In path [iid]: Instability in the schema detected. Using multiple representation.
# └ @ JsonGrinder C:\Users\aleca\.julia\packages\JsonGrinder\HGYbL\src\schema\schema.jl:13
# ┌ Info: In path [type]: Instability in the schema detected. Using multiple representation.
# └ @ JsonGrinder C:\Users\aleca\.julia\packages\JsonGrinder\HGYbL\src\schema\schema.jl:13
# ┌ Info: In path [desired_access]: Instability in the schema detected. Using multiple representation.
# └ @ JsonGrinder C:\Users\aleca\.julia\packages\JsonGrinder\HGYbL\src\schema\schema.jl:13
# [Dict]  # updated = 32
#   ├── processtree: [List]  # updated = 32
#   │                  ╰── [Dict]  # updated = 84
#   │                        ├────── children: [List]  # updated = 84
#   │                        │                   ╰── [Dict]  # updated = 10
#   │                        │                         ├────── children: [List]  # updated = 10
#   │                        │                         │                   ╰── [Dict]  # updated = 35
#   │                        │                         │                         ├────── children: [List]  # updated = 35
#   │                        │                         │                         │                   ╰── [Dict]  # updated = 2
#   │                        │                         │                         │                         ├────── children: [Empty List]  # updated = 2
#   │                        │                         │                         │                         │                   ╰── Nothing
#   │                        │                         │                         │                         ├── command_line: [Scalar - String], 2 unique values  # updated = 2
#   │                        │                         │                         │                         ├── process_name: [Scalar - String], 2 unique values  # updated = 2
#   │                        │                         │                         │                         ├────────── ppid: [Scalar - Int64], 2 unique values  # updated = 2
#   │                        │                         │                         │                         ├───────── track: [Scalar - Bool], 1 unique values  # updated = 2
#   │                        │                         │                         │                         ├──── first_seen: [Scalar - Float64], 2 unique values  # updated = 2
#   │                        │                         │                         │                         ╰─────────── pid: [Scalar - Int64], 2 unique values  # updated = 2
#   │                        │                         │                         ├── command_line: [Scalar - String], 3 unique values  # updated = 35
#   │                        │                         │                         ├── process_name: [Scalar - String], 3 unique values  # updated = 35
#   │                        │                         │                         ├────────── ppid: [Scalar - Int64], 2 unique values  # updated = 35
#   │                        │                         │                         ├───────── track: [Scalar - Bool], 1 unique values  # updated = 35
#   │                        │                         │                         ├──── first_seen: [Scalar - Float64], 35 unique values  # updated = 35
#   │                        │                         │                         ╰─────────── pid: [Scalar - Int64], 35 unique values  # updated = 35
#   │                        │                         ├── command_line: [Scalar - String], 9 unique values  # updated = 10
#   │                        │                         ├── process_name: [Scalar - String], 8 unique values  # updated = 10
#   │                        │                         ├────────── ppid: [Scalar - Int64], 6 unique values  # updated = 10
#   │                        │                         ├───────── track: [Scalar - Bool], 1 unique values  # updated = 10
#   │                        │                         ├──── first_seen: [Scalar - Float64], 10 unique values  # updated = 10
#   │                        │                         ╰─────────── pid: [Scalar - Int64], 9 unique values  # updated = 10
#   │                        ├── command_line: [Scalar - String], 44 unique values  # updated = 84
#   │                        ├── process_name: [Scalar - String], 36 unique values  # updated = 84
#   │                        ├────────── ppid: [Scalar - Int64], 35 unique values  # updated = 84
#   │                        ├───────── track: [Scalar - Bool], 2 unique values  # updated = 84
#   │                        ├──── first_seen: [Scalar - Float64], 84 unique values  # updated = 84
#   │                        ╰─────────── pid: [Scalar - Int64], 42 unique values  # updated = 84
#   ├────── generic: [List]  # updated = 32
#   │                  ╰── [Dict]  # updated = 131
#   │                        ├── process_name: [Scalar - String], 41 unique values  # updated = 131
#   │                        ├── process_path: [Scalar - String], 45 unique values  # updated = 131
#   │                        ├────────── ppid: [Scalar - Int64], 42 unique values  # updated = 131
#   │                        ├─────── summary: [Dict]  # updated = 131
#   │                        │                   ├───────────────── mutex: [List]  # updated = 20
#   │                        │                   │                           ╰── [Scalar - String], 194 unique values  # updated = 215
#   │                        │                   ├────────── file_created: [List]  # updated = 51
#   │                        │                   │                           ╰── [Scalar - String], 107 unique values  # updated = 118
#   │                        │                   ├────────── command_line: [List]  # updated = 13
#   │                        │                   │                           ╰── [Scalar - String], 15 unique values  # updated = 16
#   │                        │                   ├─────────── file_opened: [List]  # updated = 44
#   │                        │                   │                           ╰── [Scalar - String], 628 unique values  # updated = 888
#   │                        │                   ├───────── connects_host: [List]  # updated = 4
#   │                        │                   │                           ╰── [Scalar - String], 11 unique values  # updated = 11
#   │                        │                   ├──────────── dll_loaded: [List]  # updated = 78
#   │                        │                   │                           ╰── [Scalar - String], 235 unique values  # updated = 1208
#   │                        │                   ├─────────── connects_ip: [List]  # updated = 4
#   │                        │                   │                           ╰── [Scalar - String], 4 unique values  # updated = 5
#   │                        │                   ├───────── regkey_opened: [List]  # updated = 73
#   │                        │                   │                           ╰── [Scalar - String], 1729 unique values  # updated = 3232
#   │                        │                   ├───────────── file_read: [List]  # updated = 29
#   │                        │                   │                           ╰── [Scalar - String], 110 unique values  # updated = 154
#   │                        │                   ├──────────── file_moved: [List]  # updated = 3
#   │                        │                   │                           ╰── [List]  # updated = 5
#   │                        │                   │                                 ╰── [Scalar - String], 7 unique values  # updated = 10
#   │                        │                   ├───────── resolves_host: [List]  # updated = 4
#   │                        │                   │                           ╰── [Scalar - String], 6 unique values  # updated = 10
#   │                        │                   ├─────────── regkey_read: [List]  # updated = 85
#   │                        │                   │                           ╰── [Scalar - String], 4891 unique values  # updated = 8813
#   │                        │                   ├─────────── fetches_url: [List]  # updated = 1
#   │                        │                   │                           ╰── [Scalar - String], 1 unique values  # updated = 1
#   │                        │                   ├── directory_enumerated: [List]  # updated = 20
#   │                        │                   │                           ╰── [Scalar - String], 1386 unique values  # updated = 1826
#   │                        │                   ├─────────── file_failed: [List]  # updated = 60
#   │                        │                   │                           ╰── [Scalar - String], 174 unique values  # updated = 230
#   │                        │                   ├──────── downloads_file: [List]  # updated = 2
#   │                        │                   │                           ╰── [Scalar - String], 1 unique values  # updated = 2
#   │                        │                   ├────────── file_written: [List]  # updated = 16
#   │                        │                   │                           ╰── [Scalar - String], 53 unique values  # updated = 67
#   │                        │                   ├─────────── file_exists: [List]  # updated = 66
#   │                        │                   │                           ╰── [Scalar - String], 288 unique values  # updated = 551
#   │                        │                   ├──────── regkey_deleted: [List]  # updated = 9
#   │                        │                   │                           ╰── [Scalar - String], 17 unique values  # updated = 24
#   │                        │                   ├───── directory_removed: [List]  # updated = 3
#   │                        │                   │                           ╰── [Scalar - String], 3 unique values  # updated = 5
#   │                        │                   ├─────────── file_copied: [List]  # updated = 3
#   │                        │                   │                           ╰── [List]  # updated = 3
#   │                        │                   │                                 ╰── [Scalar - String], 6 unique values  # updated = 6
#   │                        │                   ├──────── file_recreated: [List]  # updated = 13
#   │                        │                   │                           ╰── [Scalar - String], 30 unique values  # updated = 44
#   │                        │                   ├────────── file_deleted: [List]  # updated = 49
#   │                        │                   │                           ╰── [Scalar - String], 64 unique values  # updated = 70
#   │                        │                   ├────────────────── guid: [List]  # updated = 58
#   │                        │                   │                           ╰── [Scalar - String], 193 unique values  # updated = 418
#   │                        │                   ├──────── regkey_written: [List]  # updated = 21
#   │                        │                   │                           ╰── [Scalar - String], 119 unique values  # updated = 153
#   │                        │                   ├───────────── wmi_query: [List]  # updated = 1
#   │                        │                   │                           ╰── [Scalar - String], 1 unique values  # updated = 1
#   │                        │                   ╰───── directory_created: [List]  # updated = 13
#   │                        │                                               ╰── [Scalar - String], 37 unique values  # updated = 64
#   │                        ├──── first_seen: [Scalar - Float64], 131 unique values  # updated = 131
#   │                        ╰─────────── pid: [Scalar - Int64], 85 unique values  # updated = 131
#   ├────── summary: [Dict]  # updated = 28
#   │                  ├───────────────── mutex: [List]  # updated = 10
#   │                  │                           ╰── [Scalar - String], 194 unique values  # updated = 197
#   │                  ├────────── file_created: [List]  # updated = 12
#   │                  │                           ╰── [Scalar - String], 107 unique values  # updated = 117
#   │                  ├────────── command_line: [List]  # updated = 6
#   │                  │                           ╰── [Scalar - String], 15 unique values  # updated = 15
#   │                  ├─────────── file_opened: [List]  # updated = 25
#   │                  │                           ╰── [Scalar - String], 628 unique values  # updated = 807
#   │                  ├───────── connects_host: [List]  # updated = 4
#   │                  │                           ╰── [Scalar - String], 11 unique values  # updated = 11
#   │                  ├──────────── dll_loaded: [List]  # updated = 27
#   │                  │                           ╰── [Scalar - String], 235 unique values  # updated = 677
#   │                  ├─────────── connects_ip: [List]  # updated = 3
#   │                  │                           ╰── [Scalar - String], 4 unique values  # updated = 4
#   │                  ├───────── regkey_opened: [List]  # updated = 24
#   │                  │                           ╰── [Scalar - String], 1729 unique values  # updated = 2580
#   │                  ├───────────── file_read: [List]  # updated = 16
#   │                  │                           ╰── [Scalar - String], 110 unique values  # updated = 140
#   │                  ├──────────── file_moved: [List]  # updated = 3
#   │                  │                           ╰── [List]  # updated = 5
#   │                  │                                 ╰── [Scalar - String], 7 unique values  # updated = 10
#   │                  ├───────── resolves_host: [List]  # updated = 3
#   │                  │                           ╰── [Scalar - String], 6 unique values  # updated = 10
#   │                  ├─────────── regkey_read: [List]  # updated = 26
#   │                  │                           ╰── [Scalar - String], 4891 unique values  # updated = 7996
#   │                  ├─────────── fetches_url: [List]  # updated = 1
#   │                  │                           ╰── [Scalar - String], 1 unique values  # updated = 1
#   │                  ├── directory_enumerated: [List]  # updated = 13
#   │                  │                           ╰── [Scalar - String], 1386 unique values  # updated = 1422
#   │                  ├─────────── file_failed: [List]  # updated = 15
#   │                  │                           ╰── [Scalar - String], 174 unique values  # updated = 181
#   │                  ├──────── downloads_file: [List]  # updated = 2
#   │                  │                           ╰── [Scalar - String], 1 unique values  # updated = 2
#   │                  ├────────── file_written: [List]  # updated = 11
#   │                  │                           ╰── [Scalar - String], 53 unique values  # updated = 66
#   │                  ├─────────── file_exists: [List]  # updated = 21
#   │                  │                           ╰── [Scalar - String], 288 unique values  # updated = 324
#   │                  ├──────── regkey_deleted: [List]  # updated = 5
#   │                  │                           ╰── [Scalar - String], 17 unique values  # updated = 20
#   │                  ├───── directory_removed: [List]  # updated = 3
#   │                  │                           ╰── [Scalar - String], 3 unique values  # updated = 5
#   │                  ├─────────── file_copied: [List]  # updated = 3
#   │                  │                           ╰── [List]  # updated = 3
#   │                  │                                 ╰── [Scalar - String], 6 unique values  # updated = 6
#   │                  ├──────── file_recreated: [List]  # updated = 7
#   │                  │                           ╰── [Scalar - String], 30 unique values  # updated = 35
#   │                  ├────────── file_deleted: [List]  # updated = 11
#   │                  │                           ╰── [Scalar - String], 64 unique values  # updated = 70
#   │                  ├────────────────── guid: [List]  # updated = 11
#   │                  │                           ╰── [Scalar - String], 193 unique values  # updated = 299
#   │                  ├──────── regkey_written: [List]  # updated = 9
#   │                  │                           ╰── [Scalar - String], 119 unique values  # updated = 147
#   │                  ├───────────── wmi_query: [List]  # updated = 1
#   │                  │                           ╰── [Scalar - String], 1 unique values  # updated = 1
#   │                  ╰───── directory_created: [List]  # updated = 7
#   │                                              ╰── [Scalar - String], 37 unique values  # updated = 54
#   ├───── apistats: [Dict]  # updated = 29
#   │                  ├── 2080: [Dict]  # updated = 2
#   │                  │           ├──────────────────────── LoadStringW: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├──────────── NtAllocateVirtualMemory: [Scalar - Int64], 2 unique values  # updated = 2
#   │                  │           ├─────────────────────── LdrUnloadDll: [Scalar - Int64], 2 unique values  # updated = 2
#   │                  │           ├────────────────────── NtOpenSection: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├────────────────────── CreateActCtxW: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├──────────────────────────── NtClose: [Scalar - Int64], 2 unique values  # updated = 2
#   │                  │           ├──────────────────────── GetFileType: [Scalar - Int64], 1 unique values  # updated = 2
#   │                  │           ├───────────────────── OpenSCManagerW: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├─────────────────────── SetEndOfFile: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├─── GetVolumePathNamesForVolumeNameW: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├───────────────────── SetFilePointer: [Scalar - Int64], 2 unique values  # updated = 2
#   │                  │           ├─────────────────────── GetTempPathW: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├────────────────────── FindResourceW: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├──────────────────────── NtCreateKey: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├───────────────── NtMapViewOfSection: [Scalar - Int64], 2 unique values  # updated = 2
#   │                  │           ├─────────────────── RegQueryValueExA: [Scalar - Int64], 1 unique values  # updated = 2
#   │                  │           ├──────────────────── NtQueryValueKey: [Scalar - Int64], 2 unique values  # updated = 2
#   │                  │           ├────────────────── NtDuplicateObject: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├───────────────────────── LdrLoadDll: [Scalar - Int64], 2 unique values  # updated = 2
#   │                  │           ├─────────────── NtSetInformationFile: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├─────────────────── NtCreateThreadEx: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├───────────────── GlobalMemoryStatus: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├────────────────────────── NtOpenKey: [Scalar - Int64], 2 unique values  # updated = 2
#   │                  │           ├────────────────── SetWindowsHookExA: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├─────────────────── CoGetClassObject: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├───────────────────── CoUninitialize: [Scalar - Int64], 2 unique values  # updated = 2
#   │                  │           ├─────────────────── GetSystemMetrics: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├─────────────── NtUnmapViewOfSection: [Scalar - Int64], 2 unique values  # updated = 2
#   │                  │           ├───────────────────────── NtReadFile: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├──────────────────────── NtDeleteKey: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├───────────────────── NtResumeThread: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├──────────────────── NtCreateSection: [Scalar - Int64], 2 unique values  # updated = 2
#   │                  │           ├─────────────────────── OpenServiceW: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├──────────────────── DeviceIoControl: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├───────────────────── CoInitializeEx: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├───────────────────────── NtOpenFile: [Scalar - Int64], 2 unique values  # updated = 2
#   │                  │           ├─────────────────────── LoadResource: [Scalar - Int64], 2 unique values  # updated = 2
#   │                  │           ├─────────────────── CoCreateInstance: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├──────────────────────── GetFileSize: [Scalar - Int64], 1 unique values  # updated = 2
#   │                  │           ├───────────────── GetFileAttributesW: [Scalar - Int64], 2 unique values  # updated = 2
#   │                  │           ├──────────────────────── SearchPathW: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├───────────────────────── UuidCreate: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├───────── GetSystemWindowsDirectoryW: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├─────────── NtQuerySystemInformation: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├──────────────── NtEnumerateValueKey: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├────────────────────── RegOpenKeyExW: [Scalar - Int64], 2 unique values  # updated = 2
#   │                  │           ├───────────── NtProtectVirtualMemory: [Scalar - Int64], 2 unique values  # updated = 2
#   │                  │           ├─────────────────────── NtCreateFile: [Scalar - Int64], 2 unique values  # updated = 2
#   │                  │           ├───────────────────── NtEnumerateKey: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├──────────────────── FindResourceExW: [Scalar - Int64], 2 unique values  # updated = 2
#   │                  │           ├──────────────────────── LoadStringA: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├──────────────────────── SetFileTime: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├── GetVolumeNameForVolumeMountPointW: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├──────── SetUnhandledExceptionFilter: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├───────────────────────── NtQueryKey: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├──────────────────────── timeGetTime: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├───────────── NtQueryInformationFile: [Scalar - Int64], 2 unique values  # updated = 2
#   │                  │           ├──────────────── GetNativeSystemInfo: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├────────────────────── RegEnumKeyExW: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├─────────────────── NtDelayExecution: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├───────────────── NtTerminateProcess: [Scalar - Int64], 2 unique values  # updated = 2
#   │                  │           ├─────────────────────── CreateThread: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├────────────────────── RegOpenKeyExA: [Scalar - Int64], 2 unique values  # updated = 2
#   │                  │           ├──────────────────── LdrGetDllHandle: [Scalar - Int64], 2 unique values  # updated = 2
#   │                  │           ├──────────────────────── DeleteFileW: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├────────────── NtQueryAttributesFile: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├─────────────────────── GetCursorPos: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├────────────────────── NtSetValueKey: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├──────────────────── RegCreateKeyExW: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├──────────── GetSystemTimeAsFileTime: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├───────────────────── RegSetValueExW: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├──────────────── GetSystemDirectoryW: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├───────── SHGetSpecialFolderLocation: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├──────────────────────── RegCloseKey: [Scalar - Int64], 2 unique values  # updated = 2
#   │                  │           ├────────────────────── __exception__: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├───────────── LdrGetProcedureAddress: [Scalar - Int64], 2 unique values  # updated = 2
#   │                  │           ├─────────────────────── SetErrorMode: [Scalar - Int64], 2 unique values  # updated = 2
#   │                  │           ├─────────────────── RegQueryValueExW: [Scalar - Int64], 2 unique values  # updated = 2
#   │                  │           ├───────────────────── NtCreateMutant: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├──────────────── UnhookWindowsHookEx: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├────────────────────── OleInitialize: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├────────────── NtDeviceIoControlFile: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├────────────────────── GetSystemInfo: [Scalar - Int64], 2 unique values  # updated = 2
#   │                  │           ├──────────────── NtFreeVirtualMemory: [Scalar - Int64], 2 unique values  # updated = 2
#   │                  │           ├──────────────────────── NtOpenKeyEx: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ╰─────────────── CryptAcquireContextW: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  ├── 3760: [Dict]  # updated = 1
#   │                  │           ├── RtlAddVectoredExceptionHandler: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├─────────────── ReadProcessMemory: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├──────────── NtQueryDirectoryFile: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├───────── NtAllocateVirtualMemory: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├──────────────────── LdrUnloadDll: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├─────────────────── CreateActCtxW: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├────── GetSystemWindowsDirectoryA: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├───────────────────────── NtClose: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├───────────────────── GetFileType: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├─────────── NtOpenDirectoryObject: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├────────────── WriteProcessMemory: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├────────────────── SetFilePointer: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├─────────────────── FindResourceW: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├──────────── CertOpenSystemStoreW: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├────────────── NtMapViewOfSection: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├──────────────── RegQueryValueExA: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├───────────────── NtQueryValueKey: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├─────────────── NtDuplicateObject: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├────────────────────── LdrLoadDll: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├─────────────────── NtOpenProcess: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├──────────────── NtCreateThreadEx: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├────────────── GlobalMemoryStatus: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├─────────────────────── NtOpenKey: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├─────────────────── WriteConsoleW: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├──────────────── CoGetClassObject: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├──────────────── SetFilePointerEx: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├────────────────── CoUninitialize: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├──────────────── GetSystemMetrics: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├────────── GetTimeZoneInformation: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├────────────────────── NtReadFile: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├────────────────── NtResumeThread: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├──────────────────── NtOpenThread: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├───────────────── NtCreateSection: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├────────────────── CoInitializeEx: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├──────────── GlobalMemoryStatusEx: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├──────────────────── LoadResource: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├────────────────────── NtOpenFile: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├──────────────── CoCreateInstance: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├───────────────────── GetFileSize: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├───────── GetFileVersionInfoSizeW: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├────────────── GetFileAttributesW: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├────────────────────── UuidCreate: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├────── GetSystemWindowsDirectoryW: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├──────── NtQuerySystemInformation: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├──────────────── FindFirstFileExW: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├─────────────────── RegOpenKeyExW: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├──────────────── CreateDirectoryW: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├──────────────────── NtCreateFile: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├────────── NtProtectVirtualMemory: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├────────────────── GetUserNameExW: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├──────────────── SHGetFolderPathW: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├───────────────── CryptCreateHash: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├────────────── CoCreateInstanceEx: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├───── SetUnhandledExceptionFilter: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├────────────────── SizeofResource: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├────────────────────── NtQueryKey: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├────────── NtQueryInformationFile: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├───────────── GetNativeSystemInfo: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├──────────────── NtDelayExecution: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├──────────────────── CreateThread: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├─────────────────── RegOpenKeyExA: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├───────────────────── RegEnumKeyW: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├───────────────── LdrGetDllHandle: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├──────────── CoInitializeSecurity: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├─────────── NtQueryAttributesFile: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├───────────────────── DeleteFileW: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├─────────────────── CryptHashData: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├──────────────── GetComputerNameW: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├───────────────── RegCreateKeyExW: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├──────────── GetFileAttributesExW: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├───────── GetSystemTimeAsFileTime: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├───────────────────── NtWriteFile: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├────────────────────── WSAStartup: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├────────────────── RegSetValueExW: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├───────────── GetSystemDirectoryW: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├──────────────── RegQueryInfoKeyW: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├───────────────────── RegCloseKey: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├────────── LdrGetProcedureAddress: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├──────────────────── SetErrorMode: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├────────────── GetVolumePathNameW: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├─────────────────── GetFileSizeEx: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├──────────────── RegQueryValueExW: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├────────────────── NtCreateMutant: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├─────────────────── GetSystemInfo: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├───────────── NtFreeVirtualMemory: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├───────────── GetFileVersionInfoW: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├─────────── LookupPrivilegeValueW: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ╰──────────── CryptAcquireContextW: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  ├── 2868: [Dict]  # updated = 1
#   │                  │           ├─────────────── GetAdaptersAddresses: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├────────────────── ReadProcessMemory: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├──────────── NtAllocateVirtualMemory: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├─────────────────────── LdrUnloadDll: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├────────────────────── NtOpenSection: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├──────────────────────────── NtClose: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├────────────── NtOpenDirectoryObject: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├───────────────── WriteProcessMemory: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├─────────────────────────────── bind: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├─────────────────── RegQueryValueExA: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├──────────────────── NtQueryValueKey: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├────────────────── NtDuplicateObject: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├───────────────────────── LdrLoadDll: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├────────────────────── NtOpenProcess: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├──────────────── InternetCloseHandle: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├─────────────────── NtCreateThreadEx: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├────────────────────────── NtOpenKey: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├─────────────────── SetFilePointerEx: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├─────────────── NtUnmapViewOfSection: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├───────────────────────── NtReadFile: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├──────────────────── Process32FirstW: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├───────────────────── NtResumeThread: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├───────────────── CreateRemoteThread: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├────────────────────── InternetOpenA: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├─────────────────────── NtOpenThread: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├────────────── MoveFileWithProgressW: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├───────────────────── CoInitializeEx: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├─────────────── GlobalMemoryStatusEx: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├─────────────────── CoCreateInstance: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├──────────── GetFileVersionInfoSizeW: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├───────────────── GetFileAttributesW: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├───────────────────────── UuidCreate: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├─────────── NtQuerySystemInformation: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├─────────────────── FindFirstFileExW: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├────────────────────── RegOpenKeyExW: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├───────────── NtProtectVirtualMemory: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├─────────────────────── NtCreateFile: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├─────────────────── SHGetFolderPathW: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├──────────────────── FindResourceExW: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├──────────────────── CryptCreateHash: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├── GetVolumeNameForVolumeMountPointW: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├─────────────────── HttpOpenRequestA: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├───────────────────────── NtQueryKey: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├───────────────────── OpenSCManagerA: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├──────────────────────── getaddrinfo: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├───────────────────── Process32NextW: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├─────────────────── NtDelayExecution: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├─────────────────────── CreateThread: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├───────────────── InternetSetOptionA: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├────────────────────── RegOpenKeyExA: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├──────────────────── LdrGetDllHandle: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├────────────────────── CryptHashData: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├───────────────────────────── socket: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├──────────────────── RegCreateKeyExW: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├──────────── GetSystemTimeAsFileTime: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├─────────────────── InternetConnectA: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├───────────────────────── WSAStartup: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├───────────────────── RegSetValueExW: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├──────────────── GetSystemDirectoryW: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├──────────────────── RegCreateKeyExA: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├─────────────────── RegQueryInfoKeyW: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├──────────────────────── RegCloseKey: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├───────────── LdrGetProcedureAddress: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├─────────────────────── SetErrorMode: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├────────────────── InternetCrackUrlA: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├────────────────────── GetFileSizeEx: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├──────────────── GetSystemDirectoryA: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├───────────────────── NtCreateMutant: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├─────────────────── RegQueryValueExW: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├────────────── NtDeviceIoControlFile: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├───────────────────────────── listen: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├────────────────────── GetSystemInfo: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├──────────────── NtFreeVirtualMemory: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├──────────────── GetFileVersionInfoW: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├─────────── CreateToolhelp32Snapshot: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├───────────────────── RegSetValueExA: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├─────────────── InternetQueryOptionA: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├──────────────────────── getsockname: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├────────────── ObtainUserAgentString: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├─────────────────── HttpSendRequestA: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├─────────────────────── OpenServiceA: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ╰─────────────── CryptAcquireContextW: [Scalar - Int64], 1 unique values  # updated = 1
# ...
#   │                  ├── 2436: [Dict]  # updated = 2
#   │                  │           ├──────────────────────── LoadStringW: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├───── RtlAddVectoredExceptionHandler: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├────────────────── ReadProcessMemory: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├─────────────── NtQueryDirectoryFile: [Scalar - Int64], 2 unique values  # updated = 2
#   │                  │           ├──────────── NtAllocateVirtualMemory: [Scalar - Int64], 2 unique values  # updated = 2
#   │                  │           ├─────────────────────── LdrUnloadDll: [Scalar - Int64], 2 unique values  # updated = 2
#   │                  │           ├────────────────────── NtOpenSection: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├────────────────────── CreateActCtxW: [Scalar - Int64], 2 unique values  # updated = 2
#   │                  │           ├───────── GetSystemWindowsDirectoryA: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├──────────────────────────── NtClose: [Scalar - Int64], 2 unique values  # updated = 2
#   │                  │           ├──────────────────────── GetFileType: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├───────────────────── OpenSCManagerW: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├────────────── NtOpenDirectoryObject: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├─────────────────────── SetEndOfFile: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├───────────────────── SetFilePointer: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├────────────────────── FindResourceW: [Scalar - Int64], 2 unique values  # updated = 2
#   │                  │           ├──────────────────────── GetKeyState: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├──────────────────────── NtCreateKey: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├───────────────── NtMapViewOfSection: [Scalar - Int64], 2 unique values  # updated = 2
#   │                  │           ├─────────────────── RegQueryValueExA: [Scalar - Int64], 2 unique values  # updated = 2
#   │                  │           ├────────────────────── CertOpenStore: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├─────────────── CryptAcquireContextA: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├──────────────── CryptDecodeObjectEx: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├────────────────── NtDuplicateObject: [Scalar - Int64], 2 unique values  # updated = 2
#   │                  │           ├───────────────────────── LdrLoadDll: [Scalar - Int64], 2 unique values  # updated = 2
#   │                  │           ├──────────────────── NtQueryValueKey: [Scalar - Int64], 2 unique values  # updated = 2
#   │                  │           ├────────────────────── NtOpenProcess: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├─────────────── NtSetInformationFile: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├──────────────────────── CryptGenKey: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├─────────────────── NtCreateThreadEx: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├───────────────── GlobalMemoryStatus: [Scalar - Int64], 2 unique values  # updated = 2
#   │                  │           ├────────────────────────── NtOpenKey: [Scalar - Int64], 2 unique values  # updated = 2
#   │                  │           ├────────────────── NtTerminateThread: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├─────────────────── CoGetClassObject: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├─────────────────── SetFilePointerEx: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├───────────────────── CoUninitialize: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├───────── GetFileInformationByHandle: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├── RtlRemoveVectoredExceptionHandler: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├─────────────────── GetSystemMetrics: [Scalar - Int64], 2 unique values  # updated = 2
#   │                  │           ├─────────────── NtUnmapViewOfSection: [Scalar - Int64], 2 unique values  # updated = 2
#   │                  │           ├───────────── GetTimeZoneInformation: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├───────────────────────── NtReadFile: [Scalar - Int64], 2 unique values  # updated = 2
#   │                  │           ├───────────────────── NtResumeThread: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├─────────────────────── NtOpenThread: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├──────────────────── NtCreateSection: [Scalar - Int64], 2 unique values  # updated = 2
#   │                  │           ├─────────────────────── OpenServiceW: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├──────────────────── DeviceIoControl: [Scalar - Int64], 2 unique values  # updated = 2
#   │                  │           ├───────────────────── CoInitializeEx: [Scalar - Int64], 2 unique values  # updated = 2
#   │                  │           ├───────────────────────── NtOpenFile: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├─────────────────────── LoadResource: [Scalar - Int64], 2 unique values  # updated = 2
#   │                  │           ├─────────────── GlobalMemoryStatusEx: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├─────────────────── CoCreateInstance: [Scalar - Int64], 2 unique values  # updated = 2
#   │                  │           ├──────────────────────── GetFileSize: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├──────────── GetFileVersionInfoSizeW: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├───────────────── GetFileAttributesW: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├───────────────────────── UuidCreate: [Scalar - Int64], 2 unique values  # updated = 2
#   │                  │           ├────────────────────── StartServiceA: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├───────── GetSystemWindowsDirectoryW: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├─────────── NtQuerySystemInformation: [Scalar - Int64], 2 unique values  # updated = 2
#   │                  │           ├─────────────────── FindFirstFileExW: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├──────────────── NtEnumerateValueKey: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├────────────────────── RegOpenKeyExW: [Scalar - Int64], 2 unique values  # updated = 2
#   │                  │           ├─────────────────── CreateDirectoryW: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├─────────────────────── NtCreateFile: [Scalar - Int64], 2 unique values  # updated = 2
#   │                  │           ├───────────── NtProtectVirtualMemory: [Scalar - Int64], 2 unique values  # updated = 2
#   │                  │           ├────────────────────── RegEnumValueW: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├─────────────────── SHGetFolderPathW: [Scalar - Int64], 2 unique values  # updated = 2
#   │                  │           ├───────────────────── NtEnumerateKey: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├─────────────────── RemoveDirectoryW: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├──────────────────── FindResourceExW: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├───────────────── SetFileAttributesW: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├────────────────── LookupAccountSidW: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├────────────────────── FindResourceA: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├──────────────────────── LoadStringA: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├──────────────────────── DrawTextExW: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├─────────────────── CryptProtectData: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├── GetVolumeNameForVolumeMountPointW: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├─────────────────── CertControlStore: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├───────────────────── SizeofResource: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├───────────────────────── NtQueryKey: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├───────────────────── OpenSCManagerA: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├───────────── NtQueryInformationFile: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├──────────────── GetNativeSystemInfo: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├─────────────────── NtDelayExecution: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├─────────────────────── CreateThread: [Scalar - Int64], 2 unique values  # updated = 2
#   │                  │           ├───────────────── NtTerminateProcess: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├─────── InternetGetConnectedStateExA: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├────────────────────── RegOpenKeyExA: [Scalar - Int64], 2 unique values  # updated = 2
#   │                  │           ├──────────────────── LdrGetDllHandle: [Scalar - Int64], 2 unique values  # updated = 2
#   │                  │           ├────────────── NtQueryAttributesFile: [Scalar - Int64], 2 unique values  # updated = 2
#   │                  │           ├──────────────────────── DeleteFileW: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├────────────────────── CryptHashData: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├─────────────────── GetComputerNameW: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├─────────────────────── GetCursorPos: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├────────────────────── NtSetValueKey: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├──────────────────── RegCreateKeyExW: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├──────────────────── RegDeleteValueW: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├──────────── GetSystemTimeAsFileTime: [Scalar - Int64], 2 unique values  # updated = 2
#   │                  │           ├──────────────────────── NtWriteFile: [Scalar - Int64], 2 unique values  # updated = 2
#   │                  │           ├───────────────────────── WSAStartup: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├───────────────── CryptUnprotectData: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├───────────────────── RegSetValueExW: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├───────────────── CreateDirectoryExW: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├──────────────────── RegCreateKeyExA: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├─────────────────── RegQueryInfoKeyW: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├──────────────── GetSystemDirectoryW: [Scalar - Int64], 1 unique values  # updated = 2
#   │                  │           ├──────────────── NtReadVirtualMemory: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├──────────────────────── RegCloseKey: [Scalar - Int64], 2 unique values  # updated = 2
#   │                  │           ├───────────── LdrGetProcedureAddress: [Scalar - Int64], 2 unique values  # updated = 2
#   │                  │           ├─────────────────────── SetErrorMode: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├───────────────── GetVolumePathNameW: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├─────────────────── RegQueryValueExW: [Scalar - Int64], 2 unique values  # updated = 2
#   │                  │           ├───────────────────── NtCreateMutant: [Scalar - Int64], 2 unique values  # updated = 2
#   │                  │           ├────────────── NtDeviceIoControlFile:
# Excessive output truncated after 524331 bytes.
# [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├────────────────────── OleInitialize: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├──────────────── GetForegroundWindow: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├────────────────────── GetSystemInfo: [Scalar - Int64], 2 unique values  # updated = 2
#   │                  │           ├──────────────── NtFreeVirtualMemory: [Scalar - Int64], 2 unique values  # updated = 2
#   │                  │           ├───────────────────── RegSetValueExA: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├──────────────────────── NtOpenKeyEx: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├─────────────── InternetQueryOptionA: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ╰─────────────────────── OpenServiceA: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  ├── 2856: [Dict]  # updated = 1
#   │                  │           ├──────────────────────── LoadStringW: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├─────────────── NtQueryDirectoryFile: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├──────────── NtAllocateVirtualMemory: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├─────────────────────── LdrUnloadDll: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├────────────────────── NtOpenSection: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├────────────────────── CreateActCtxW: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├──────────────────────────── NtClose: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├───────────────────── OpenSCManagerW: [Scalar - Int64], 1 unique values  # updated = 1
#   │                  │           ├─────────────────── GetKeyboardState:

# %%
extractor=suggestextractor(complete_schema);
data=map(extractor,jsons);
# Out:
# ┌ Warning: [:processtree][:children][:children][:children]: key children contains empty array, skipping
# └ @ JsonGrinder C:\Users\aleca\.julia\packages\JsonGrinder\HGYbL\src\schema\dict.jl:61
# ┌ Warning: [:processes][:calls]: key stacktrace contains empty array, skipping
# └ @ JsonGrinder C:\Users\aleca\.julia\packages\JsonGrinder\HGYbL\src\schema\dict.jl:61
# ┌ Warning: [:processes][:calls][:arguments]: key arguments contains empty array, skipping
# └ @ JsonGrinder C:\Users\aleca\.julia\packages\JsonGrinder\HGYbL\src\schema\dict.jl:61
# MethodError: no method matching val2idx(::ExtractCategorical{Number, UInt32}, ::Nothing)
# Closest candidates are:
#   val2idx(::ExtractCategorical{var"#s60", I} where var"#s60"<:Number, ::Number) where {V, I} at C:\Users\aleca\.julia\packages\JsonGrinder\HGYbL\src\extractors\extractcategorical.jl:100
#   val2idx(::ExtractCategorical{V, I}, ::V) where {V, I} at C:\Users\aleca\.julia\packages\JsonGrinder\HGYbL\src\extractors\extractcategorical.jl:99
#
# Stacktrace:
#   [1] (::ExtractCategorical{Number, UInt32})(v::String; store_input::Bool)
#     @ JsonGrinder C:\Users\aleca\.julia\packages\JsonGrinder\HGYbL\src\extractors\extractcategorical.jl:121
#   [2] (::JsonGrinder.var"#151#152"{Bool, String})(e::ExtractCategorical{Number, UInt32})
#     @ JsonGrinder C:\Users\aleca\.julia\packages\JsonGrinder\HGYbL\src\extractors\multirepresentation.jl:94
#   [3] map
#     @ .\tuple.jl:214 [inlined]
#   [4] map(::Function, ::NamedTuple{(:e1, :e2), Tuple{ExtractCategorical{String, UInt32}, ExtractCategorical{Number, UInt32}}})
#     @ Base .\namedtuple.jl:197
#   [5] (::MultipleRepresentation{NamedTuple{(:e1, :e2), Tuple{ExtractCategorical{String, UInt32}, ExtractCategorical{Number, UInt32}}}})(x::String; store_input::Bool)
#     @ JsonGrinder C:\Users\aleca\.julia\packages\JsonGrinder\HGYbL\src\extractors\multirepresentation.jl:94
#   [6] (::JsonGrinder.var"#114#115"{Bool, Dict{String, Any}})(::Pair{Symbol, Any})
#     @ JsonGrinder .\none:0
#   [7] iterate
#     @ .\generator.jl:47 [inlined]
#   [8] collect_to!(dest::Vector{Pair{Symbol, _A} where _A}, itr::Base.Generator{Dict{Symbol, Any}, JsonGrinder.var"#114#115"{Bool, Dict{String, Any}}}, offs::Int64, st::Int64)
#     @ Base .\array.jl:728
#   [9] collect_to!(dest::Vector{Pair{Symbol, ArrayNode{MaybeHotMatrix{Union{Missing, UInt32}, UInt32, Union{Missing, Bool}}, Nothing}}}, itr::Base.Generator{Dict{Symbol, Any}, JsonGrinder.var"#114#115"{Bool, Dict{String, Any}}}, offs::Int64, st::Int64)
#     @ Base .\array.jl:736
#  [10] collect_to_with_first!(dest::Vector{Pair{Symbol, ArrayNode{MaybeHotMatrix{Union{Missing, UInt32}, UInt32, Union{Missing, Bool}}, Nothing}}}, v1::Pair{Symbol, ArrayNode{MaybeHotMatrix{Union{Missing, UInt32}, UInt32, Union{Missing, Bool}}, Nothing}}, itr::Base.Generator{Dict{Symbol, Any}, JsonGrinder.var"#114#115"{Bool, Dict{String, Any}}}, st::Int64)
#     @ Base .\array.jl:706
#  [11] collect(itr::Base.Generator{Dict{Symbol, Any}, JsonGrinder.var"#114#115"{Bool, Dict{String, Any}}})
#     @ Base .\array.jl:687
#  [12] (::ExtractDict{Dict{Symbol, Any}})(v::Dict{String, Any}; store_input::Bool)
#     @ JsonGrinder C:\Users\aleca\.julia\packages\JsonGrinder\HGYbL\src\extractors\extractdict.jl:73
# --- the last 7 lines are repeated 1 more time ---
#  [20] (::JsonGrinder.var"#105#106"{Bool, ExtractArray{ExtractDict{Dict{Symbol, JsonGrinder.AbstractExtractor}}}})(x::Dict{String, Any})
#     @ JsonGrinder C:\Users\aleca\.julia\packages\JsonGrinder\HGYbL\src\extractors\extractarray.jl:53
#  [21] macro expansion
#     @ .\reduce.jl:245 [inlined]
#  [22] macro expansion
#     @ .\simdloop.jl:77 [inlined]
#  [23] mapreduce_impl(f::JsonGrinder.var"#105#106"{Bool, ExtractArray{ExtractDict{Dict{Symbol, JsonGrinder.AbstractExtractor}}}}, op::typeof(catobs), A::Vector{Any}, ifirst::Int64, ilast::Int64, blksize::Int64)
#     @ Base .\reduce.jl:243
#  [24] mapreduce_impl(f::JsonGrinder.var"#105#106"{Bool, ExtractArray{ExtractDict{Dict{Symbol, JsonGrinder.AbstractExtractor}}}}, op::typeof(catobs), A::Vector{Any}, ifirst::Int64, ilast::Int64, blksize::Int64)
#     @ Base .\reduce.jl:251
#  [25] mapreduce_impl
#     @ .\reduce.jl:257 [inlined]
#  [26] _mapreduce(f::JsonGrinder.var"#105#106"{Bool, ExtractArray{ExtractDict{Dict{Symbol, JsonGrinder.AbstractExtractor}}}}, op::typeof(catobs), #unused#::IndexLinear, A::Vector{Any})
#     @ Base .\reduce.jl:415
#  [27] _mapreduce_dim
#     @ .\reducedim.jl:318 [inlined]
#  [28] #mapreduce#678
#     @ .\reducedim.jl:310 [inlined]
#  [29] mapreduce
#     @ .\reducedim.jl:310 [inlined]
#  [30] (::ExtractArray{ExtractDict{Dict{Symbol, JsonGrinder.AbstractExtractor}}})(v::Vector{Any}; store_input::Bool)
#     @ JsonGrinder C:\Users\aleca\.julia\packages\JsonGrinder\HGYbL\src\extractors\extractarray.jl:50
#  [31] (::JsonGrinder.var"#114#115"{Bool, Dict{String, Any}})(::Pair{Symbol, JsonGrinder.AbstractExtractor})
#     @ JsonGrinder .\none:0
#  [32] iterate
#     @ .\generator.jl:47 [inlined]
#  [33] collect_to!(dest::Vector{Pair{Symbol, _A} where _A}, itr::Base.Generator{Dict{Symbol, JsonGrinder.AbstractExtractor}, JsonGrinder.var"#114#115"{Bool, Dict{String, Any}}}, offs::Int64, st::Int64)
#     @ Base .\array.jl:728
#  [34] collect_to!(dest::Vector{Pair{Symbol, ArrayNode{OneHotArrays.OneHotMatrix{UInt32, 0x0000003a, Vector{UInt32}}, Nothing}}}, itr::Base.Generator{Dict{Symbol, JsonGrinder.AbstractExtractor}, JsonGrinder.var"#114#115"{Bool, Dict{String, Any}}}, offs::Int64, st::Int64)
#     @ Base .\array.jl:736
#  [35] collect_to_with_first!(dest::Vector{Pair{Symbol, ArrayNode{OneHotArrays.OneHotMatrix{UInt32, 0x0000003a, Vector{UInt32}}, Nothing}}}, v1::Pair{Symbol, ArrayNode{OneHotArrays.OneHotMatrix{UInt32, 0x0000003a, Vector{UInt32}}, Nothing}}, itr::Base.Generator{Dict{Symbol, JsonGrinder.AbstractExtractor}, JsonGrinder.var"#114#115"{Bool, Dict{String, Any}}}, st::Int64)
#     @ Base .\array.jl:706
#  [36] collect(itr::Base.Generator{Dict{Symbol, JsonGrinder.AbstractExtractor}, JsonGrinder.var"#114#115"{Bool, Dict{String, Any}}})
#     @ Base .\array.jl:687
#  [37] (::ExtractDict{Dict{Symbol, JsonGrinder.AbstractExtractor}})(v::Dict{String, Any}; store_input::Bool)
#     @ JsonGrinder C:\Users\aleca\.julia\packages\JsonGrinder\HGYbL\src\extractors\extractdict.jl:73
#  [38] (::JsonGrinder.var"#105#106"{Bool, ExtractArray{ExtractDict{Dict{Symbol, JsonGrinder.AbstractExtractor}}}})(x::Dict{String, Any})
#     @ JsonGrinder C:\Users\aleca\.julia\packages\JsonGrinder\HGYbL\src\extractors\extractarray.jl:53
#  [39] _mapreduce(f::JsonGrinder.var"#105#106"{Bool, ExtractArray{ExtractDict{Dict{Symbol, JsonGrinder.AbstractExtractor}}}}, op::typeof(catobs), #unused#::IndexLinear, A::Vector{Any})
#     @ Base .\reduce.jl:408
#  [40] _mapreduce_dim
#     @ .\reducedim.jl:318 [inlined]
#  [41] #mapreduce#678
#     @ .\reducedim.jl:310 [inlined]
#  [42] mapreduce
#     @ .\reducedim.jl:310 [inlined]
#  [43] (::ExtractArray{ExtractDict{Dict{Symbol, JsonGrinder.AbstractExtractor}}})(v::Vector{Any}; store_input::Bool)
#     @ JsonGrinder C:\Users\aleca\.julia\packages\JsonGrinder\HGYbL\src\extractors\extractarray.jl:50
#  [44] (::JsonGrinder.var"#114#115"{Bool, Dict{String, Any}})(::Pair{Symbol, JsonGrinder.AbstractExtractor})
#     @ JsonGrinder .\none:0
#  [45] iterate
#     @ .\generator.jl:47 [inlined]
#  [46] collect_to!(dest::Vector{Pair{Symbol, _A} where _A}, itr::Base.Generator{Dict{Symbol, JsonGrinder.AbstractExtractor}, JsonGrinder.var"#114#115"{Bool, Dict{String, Any}}}, offs::Int64, st::Int64)
#     @ Base .\array.jl:728
#  [47] collect_to!(dest::Vector{Pair{Symbol, BagNode{ProductNode{NamedTuple{(:children, :command_line, :process_name, :ppid, :track, :first_seen, :pid), Tuple{BagNode{ProductNode{NamedTuple{(:children, :command_line, :process_name, :ppid, :track, :first_seen, :pid), Tuple{BagNode{ProductNode{NamedTuple{(:children, :command_line, :process_name, :ppid, :track, :first_seen, :pid), Tuple{BagNode{ProductNode{NamedTuple{(:command_line, :process_name, :ppid, :track, :first_seen, :pid), Tuple{ArrayNode{OneHotArrays.OneHotMatrix{UInt32, 0x00000003, Vector{UInt32}}, Nothing}, ArrayNode{OneHotArrays.OneHotMatrix{UInt32, 0x00000003, Vector{UInt32}}, Nothing}, ArrayNode{OneHotArrays.OneHotMatrix{UInt32, 0x00000003, Vector{UInt32}}, Nothing}, ArrayNode{OneHotArrays.OneHotMatrix{UInt32, 0x00000002, Vector{UInt32}}, Nothing}, ArrayNode{OneHotArrays.OneHotMatrix{UInt32, 0x00000003, Vector{UInt32}}, Nothing}, ArrayNode{OneHotArrays.OneHotMatrix{UInt32, 0x00000003, Vector{UInt32}}, Nothing}}}, Nothing}, AlignedBags{Int64}, Nothing}, ArrayNode{OneHotArrays.OneHotMatrix{UInt32, 0x00000004, Vector{UInt32}}, Nothing}, ArrayNode{OneHotArrays.OneHotMatrix{UInt32, 0x00000004, Vector{UInt32}}, Nothing}, ArrayNode{OneHotArrays.OneHotMatrix{UInt32, 0x00000003, Vector{UInt32}}, Nothing}, ArrayNode{OneHotArrays.OneHotMatrix{UInt32, 0x00000002, Vector{UInt32}}, Nothing}, ArrayNode{OneHotArrays.OneHotMatrix{UInt32, 0x00000024, Vector{UInt32}}, Nothing}, ArrayNode{OneHotArrays.OneHotMatrix{UInt32, 0x00000024, Vector{UInt32}}, Nothing}}}, Nothing}, AlignedBags{Int64}, Nothing}, ArrayNode{OneHotArrays.OneHotMatrix{UInt32, 0x0000000a, Vector{UInt32}}, Nothing}, ArrayNode{OneHotArrays.OneHotMatrix{UInt32, 0x00000009, Vector{UInt32}}, Nothing}, ArrayNode{OneHotArrays.OneHotMatrix{UInt32, 0x00000007, Vector{UInt32}}, Nothing}, ArrayNode{OneHotArrays.OneHotMatrix{UInt32, 0x00000002, Vector{UInt32}}, Nothing}, ArrayNode{OneHotArrays.OneHotMatrix{UInt32, 0x0000000b, Vector{UInt32}}, Nothing}, ArrayNode{OneHotArrays.OneHotMatrix{UInt32, 0x0000000a, Vector{UInt32}}, Nothing}}}, Nothing}, AlignedBags{Int64}, Nothing}, ArrayNode{OneHotArrays.OneHotMatrix{UInt32, 0x0000002d, Vector{UInt32}}, Nothing}, ArrayNode{OneHotArrays.OneHotMatrix{UInt32, 0x00000025, Vector{UInt32}}, Nothing}, ArrayNode{OneHotArrays.OneHotMatrix{UInt32, 0x00000024, Vector{UInt32}}, Nothing}, ArrayNode{OneHotArrays.OneHotMatrix{UInt32, 0x00000003, Vector{UInt32}}, Nothing}, ArrayNode{OneHotArrays.OneHotMatrix{UInt32, 0x00000055, Vector{UInt32}}, Nothing}, ArrayNode{OneHotArrays.OneHotMatrix{UInt32, 0x0000002b, Vector{UInt32}}, Nothing}}}, Nothing}, AlignedBags{Int64}, Nothing}}}, itr::Base.Generator{Dict{Symbol, JsonGrinder.AbstractExtractor}, JsonGrinder.var"#114#115"{Bool, Dict{String, Any}}}, offs::Int64, st::Int64)
#     @ Base .\array.jl:736
#  [48] collect_to_with_first!(dest::Vector{Pair{Symbol, BagNode{ProductNode{NamedTuple{(:children, :command_line, :process_name, :ppid, :track, :first_seen, :pid), Tuple{BagNode{ProductNode{NamedTuple{(:children, :command_line, :process_name, :ppid, :track, :first_seen, :pid), Tuple{BagNode{ProductNode{NamedTuple{(:children, :command_line, :process_name, :ppid, :track, :first_seen, :pid), Tuple{BagNode{ProductNode{NamedTuple{(:command_line, :process_name, :ppid, :track, :first_seen, :pid), Tuple{ArrayNode{OneHotArrays.OneHotMatrix{UInt32, 0x00000003, Vector{UInt32}}, Nothing}, ArrayNode{OneHotArrays.OneHotMatrix{UInt32, 0x00000003, Vector{UInt32}}, Nothing}, ArrayNode{OneHotArrays.OneHotMatrix{UInt32, 0x00000003, Vector{UInt32}}, Nothing}, ArrayNode{OneHotArrays.OneHotMatrix{UInt32, 0x00000002, Vector{UInt32}}, Nothing}, ArrayNode{OneHotArrays.OneHotMatrix{UInt32, 0x00000003, Vector{UInt32}}, Nothing}, ArrayNode{OneHotArrays.OneHotMatrix{UInt32, 0x00000003, Vector{UInt32}}, Nothing}}}, Nothing}, AlignedBags{Int64}, Nothing}, ArrayNode{OneHotArrays.OneHotMatrix{UInt32, 0x00000004, Vector{UInt32}}, Nothing}, ArrayNode{OneHotArrays.OneHotMatrix{UInt32, 0x00000004, Vector{UInt32}}, Nothing}, ArrayNode{OneHotArrays.OneHotMatrix{UInt32, 0x00000003, Vector{UInt32}}, Nothing}, ArrayNode{OneHotArrays.OneHotMatrix{UInt32, 0x00000002, Vector{UInt32}}, Nothing}, ArrayNode{OneHotArrays.OneHotMatrix{UInt32, 0x00000024, Vector{UInt32}}, Nothing}, ArrayNode{OneHotArrays.OneHotMatrix{UInt32, 0x00000024, Vector{UInt32}}, Nothing}}}, Nothing}, AlignedBags{Int64}, Nothing}, ArrayNode{OneHotArrays.OneHotMatrix{UInt32, 0x0000000a, Vector{UInt32}}, Nothing}, ArrayNode{OneHotArrays.OneHotMatrix{UInt32, 0x00000009, Vector{UInt32}}, Nothing}, ArrayNode{OneHotArrays.OneHotMatrix{UInt32, 0x00000007, Vector{UInt32}}, Nothing}, ArrayNode{OneHotArrays.OneHotMatrix{UInt32, 0x00000002, Vector{UInt32}}, Nothing}, ArrayNode{OneHotArrays.OneHotMatrix{UInt32, 0x0000000b, Vector{UInt32}}, Nothing}, ArrayNode{OneHotArrays.OneHotMatrix{UInt32, 0x0000000a, Vector{UInt32}}, Nothing}}}, Nothing}, AlignedBags{Int64}, Nothing}, ArrayNode{OneHotArrays.OneHotMatrix{UInt32, 0x0000002d, Vector{UInt32}}, Nothing}, ArrayNode{OneHotArrays.OneHotMatrix{UInt32, 0x00000025, Vector{UInt32}}, Nothing}, ArrayNode{OneHotArrays.OneHotMatrix{UInt32, 0x00000024, Vector{UInt32}}, Nothing}, ArrayNode{OneHotArrays.OneHotMatrix{UInt32, 0x00000003, Vector{UInt32}}, Nothing}, ArrayNode{OneHotArrays.OneHotMatrix{UInt32, 0x00000055, Vector{UInt32}}, Nothing}, ArrayNode{OneHotArrays.OneHotMatrix{UInt32, 0x0000002b, Vector{UInt32}}, Nothing}}}, Nothing}, AlignedBags{Int64}, Nothing}}}, v1::Pair{Symbol, BagNode{ProductNode{NamedTuple{(:children, :command_line, :process_name, :ppid, :track, :first_seen, :pid), Tuple{BagNode{ProductNode{NamedTuple{(:children, :command_line, :process_name, :ppid, :track, :first_seen, :pid), Tuple{BagNode{ProductNode{NamedTuple{(:children, :command_line, :process_name, :ppid, :track, :first_seen, :pid), Tuple{BagNode{ProductNode{NamedTuple{(:command_line, :process_name, :ppid, :track, :first_seen, :pid), Tuple{ArrayNode{OneHotArrays.OneHotMatrix{UInt32, 0x00000003, Vector{UInt32}}, Nothing}, ArrayNode{OneHotArrays.OneHotMatrix{UInt32, 0x00000003, Vector{UInt32}}, Nothing}, ArrayNode{OneHotArrays.OneHotMatrix{UInt32, 0x00000003, Vector{UInt32}}, Nothing}, ArrayNode{OneHotArrays.OneHotMatrix{UInt32, 0x00000002, Vector{UInt32}}, Nothing}, ArrayNode{OneHotArrays.OneHotMatrix{UInt32, 0x00000003, Vector{UInt32}}, Nothing}, ArrayNode{OneHotArrays.OneHotMatrix{UInt32, 0x00000003, Vector{UInt32}}, Nothing}}}, Nothing}, AlignedBags{Int64}, Nothing}, ArrayNode{OneHotArrays.OneHotMatrix{UInt32, 0x00000004, Vector{UInt32}}, Nothing}, ArrayNode{OneHotArrays.OneHotMatrix{UInt32, 0x00000004, Vector{UInt32}}, Nothing}, ArrayNode{OneHotArrays.OneHotMatrix{UInt32, 0x00000003, Vector{UInt32}}, Nothing}, ArrayNode{OneHotArrays.OneHotMatrix{UInt32, 0x00000002, Vector{UInt32}}, Nothing}, Arra ...
#     @ Base .\array.jl:706
#  [49] collect(itr::Base.Generator{Dict{Symbol, JsonGrinder.AbstractExtractor}, JsonGrinder.var"#114#115"{Bool, Dict{String, Any}}})
#     @ Base .\array.jl:687
#  [50] (::ExtractDict{Dict{Symbol, JsonGrinder.AbstractExtractor}})(v::Dict{String, Any}; store_input::Bool)
#     @ JsonGrinder C:\Users\aleca\.julia\packages\JsonGrinder\HGYbL\src\extractors\extractdict.jl:73
#  [51] ExtractDict
#     @ C:\Users\aleca\.julia\packages\JsonGrinder\HGYbL\src\extractors\extractdict.jl:73 [inlined]
#  [52] iterate
#     @ .\generator.jl:47 [inlined]
#  [53] _collect(c::Vector{Dict{String, Any}}, itr::Base.Generator{Vector{Dict{String, Any}}, ExtractDict{Dict{Symbol, JsonGrinder.AbstractExtractor}}}, #unused#::Base.EltypeUnknown, isz::Base.HasShape{1})
#     @ Base .\array.jl:695
#  [54] collect_similar
#     @ .\array.jl:606 [inlined]
#  [55] map(f::ExtractDict{Dict{Symbol, JsonGrinder.AbstractExtractor}}, A::Vector{Dict{String, Any}})
#     @ Base .\abstractarray.jl:2294
#  [56] top-level scope
#     @ In[9]:2
#  [57] eval
#     @ .\boot.jl:360 [inlined]

# %%
data[1]
# Out:
# UndefVarError: data not defined
#
# Stacktrace:
#  [1] top-level scope
#    @ In[10]:1
#  [2] eval
#    @ .\boot.jl:360 [inlined]
#  [3] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#    @ Base .\loading.jl:1116

# %% [markdown]
# # Define the model

# %%
labelnames = sort(unique(df_labels.label))
neurons = 32
model = reflectinmodel(complete_schema, extractor,
	k -> Dense(k, neurons, relu),
	d -> SegmentedMeanMax(d),
	fsm = Dict("" => k -> Dense(k, n_classes)),
)

minibatchsize = 10
function minibatch()
	idx = StatsBase.sample(train_indexes, minibatchsize, replace = false)
	reduce(catobs, data[idx]), Flux.onehotbatch(df_labels.label[idx], labelnames)
end

iterations = 200

function calculate_accuracy(x,y) 
    vals = tmap(x) do s
        Flux.onecold(softmax(model(s)), labelnames)[1]
    end
    mean(vals .== y)
end     
    

eval_trainset = shuffle(train_indexes)
eval_testset = shuffle(test_indexes)

cb = () -> begin
	train_acc = calculate_accuracy(data[eval_trainset], df_labels.label[eval_trainset])
	test_acc = calculate_accuracy(data[eval_testset], df_labels.label[eval_testset])
	println("accuracy: train = $train_acc, test = $test_acc")
end
ps = Flux.params(model)
loss = (x,y) -> Flux.logitcrossentropy(model(x), y)
opt = ADAM()
# Out:
# MethodError: no method matching val2idx(::ExtractCategorical{Number, UInt32}, ::Nothing)
# Closest candidates are:
#   val2idx(::ExtractCategorical{var"#s60", I} where var"#s60"<:Number, ::Number) where {V, I} at C:\Users\aleca\.julia\packages\JsonGrinder\HGYbL\src\extractors\extractcategorical.jl:100
#   val2idx(::ExtractCategorical{V, I}, ::V) where {V, I} at C:\Users\aleca\.julia\packages\JsonGrinder\HGYbL\src\extractors\extractcategorical.jl:99
#
# Stacktrace:
#   [1] (::ExtractCategorical{Number, UInt32})(v::String; store_input::Bool)
#     @ JsonGrinder C:\Users\aleca\.julia\packages\JsonGrinder\HGYbL\src\extractors\extractcategorical.jl:121
#   [2] (::JsonGrinder.var"#151#152"{Bool, String})(e::ExtractCategorical{Number, UInt32})
#     @ JsonGrinder C:\Users\aleca\.julia\packages\JsonGrinder\HGYbL\src\extractors\multirepresentation.jl:94
#   [3] map
#     @ .\tuple.jl:214 [inlined]
#   [4] map(::Function, ::NamedTuple{(:e1, :e2), Tuple{ExtractCategorical{String, UInt32}, ExtractCategorical{Number, UInt32}}})
#     @ Base .\namedtuple.jl:197
#   [5] (::MultipleRepresentation{NamedTuple{(:e1, :e2), Tuple{ExtractCategorical{String, UInt32}, ExtractCategorical{Number, UInt32}}}})(x::String; store_input::Bool)
#     @ JsonGrinder C:\Users\aleca\.julia\packages\JsonGrinder\HGYbL\src\extractors\multirepresentation.jl:94
#   [6] (::JsonGrinder.var"#114#115"{Bool, Dict{Symbol, Any}})(::Pair{Symbol, Any})
#     @ JsonGrinder .\none:0
#   [7] iterate
#     @ .\generator.jl:47 [inlined]
#   [8] collect_to!(dest::Vector{Pair{Symbol, _A} where _A}, itr::Base.Generator{Dict{Symbol, Any}, JsonGrinder.var"#114#115"{Bool, Dict{Symbol, Any}}}, offs::Int64, st::Int64)
#     @ Base .\array.jl:728
#   [9] collect_to!(dest::Vector{Pair{Symbol, ArrayNode{MaybeHotMatrix{Union{Missing, UInt32}, UInt32, Union{Missing, Bool}}, Nothing}}}, itr::Base.Generator{Dict{Symbol, Any}, JsonGrinder.var"#114#115"{Bool, Dict{Symbol, Any}}}, offs::Int64, st::Int64)
#     @ Base .\array.jl:736
#  [10] collect_to_with_first!(dest::Vector{Pair{Symbol, ArrayNode{MaybeHotMatrix{Union{Missing, UInt32}, UInt32, Union{Missing, Bool}}, Nothing}}}, v1::Pair{Symbol, ArrayNode{MaybeHotMatrix{Union{Missing, UInt32}, UInt32, Union{Missing, Bool}}, Nothing}}, itr::Base.Generator{Dict{Symbol, Any}, JsonGrinder.var"#114#115"{Bool, Dict{Symbol, Any}}}, st::Int64)
#     @ Base .\array.jl:706
#  [11] collect(itr::Base.Generator{Dict{Symbol, Any}, JsonGrinder.var"#114#115"{Bool, Dict{Symbol, Any}}})
#     @ Base .\array.jl:687
#  [12] (::ExtractDict{Dict{Symbol, Any}})(v::Dict{Symbol, Any}; store_input::Bool)
#     @ JsonGrinder C:\Users\aleca\.julia\packages\JsonGrinder\HGYbL\src\extractors\extractdict.jl:73
# --- the last 7 lines are repeated 1 more time ---
#  [20] #105
#     @ C:\Users\aleca\.julia\packages\JsonGrinder\HGYbL\src\extractors\extractarray.jl:53 [inlined]
#  [21] _mapreduce(f::JsonGrinder.var"#105#106"{Bool, ExtractArray{ExtractDict{Dict{Symbol, JsonGrinder.AbstractExtractor}}}}, op::typeof(catobs), #unused#::IndexLinear, A::Vector{Dict{Symbol, Any}})
#     @ Base .\reduce.jl:408
#  [22] _mapreduce_dim
#     @ .\reducedim.jl:318 [inlined]
#  [23] #mapreduce#678
#     @ .\reducedim.jl:310 [inlined]
#  [24] mapreduce
#     @ .\reducedim.jl:310 [inlined]
#  [25] (::ExtractArray{ExtractDict{Dict{Symbol, JsonGrinder.AbstractExtractor}}})(v::Vector{Dict{Symbol, Any}}; store_input::Bool)
#     @ JsonGrinder C:\Users\aleca\.julia\packages\JsonGrinder\HGYbL\src\extractors\extractarray.jl:50
# --- the last 13 lines are repeated 1 more time ---
#  [39] (::JsonGrinder.var"#114#115"{Bool, Dict{Symbol, Any}})(::Pair{Symbol, JsonGrinder.AbstractExtractor})
#     @ JsonGrinder .\none:0
#  [40] iterate
#     @ .\generator.jl:47 [inlined]
#  [41] collect_to!(dest::Vector{Pair{Symbol, _A} where _A}, itr::Base.Generator{Dict{Symbol, JsonGrinder.AbstractExtractor}, JsonGrinder.var"#114#115"{Bool, Dict{Symbol, Any}}}, offs::Int64, st::Int64)
#     @ Base .\array.jl:728
#  [42] collect_to!(dest::Vector{Pair{Symbol, BagNode{ProductNode{NamedTuple{(:children, :command_line, :process_name, :ppid, :track, :first_seen, :pid), Tuple{BagNode{ProductNode{NamedTuple{(:children, :command_line, :process_name, :ppid, :track, :first_seen, :pid), Tuple{BagNode{ProductNode{NamedTuple{(:children, :command_line, :process_name, :ppid, :track, :first_seen, :pid), Tuple{BagNode{ProductNode{NamedTuple{(:command_line, :process_name, :ppid, :track, :first_seen, :pid), Tuple{ArrayNode{OneHotArrays.OneHotMatrix{UInt32, 0x00000003, Vector{UInt32}}, Nothing}, ArrayNode{OneHotArrays.OneHotMatrix{UInt32, 0x00000003, Vector{UInt32}}, Nothing}, ArrayNode{OneHotArrays.OneHotMatrix{UInt32, 0x00000003, Vector{UInt32}}, Nothing}, ArrayNode{OneHotArrays.OneHotMatrix{UInt32, 0x00000002, Vector{UInt32}}, Nothing}, ArrayNode{OneHotArrays.OneHotMatrix{UInt32, 0x00000003, Vector{UInt32}}, Nothing}, ArrayNode{OneHotArrays.OneHotMatrix{UInt32, 0x00000003, Vector{UInt32}}, Nothing}}}, Nothing}, AlignedBags{Int64}, Nothing}, ArrayNode{OneHotArrays.OneHotMatrix{UInt32, 0x00000004, Vector{UInt32}}, Nothing}, ArrayNode{OneHotArrays.OneHotMatrix{UInt32, 0x00000004, Vector{UInt32}}, Nothing}, ArrayNode{OneHotArrays.OneHotMatrix{UInt32, 0x00000003, Vector{UInt32}}, Nothing}, ArrayNode{OneHotArrays.OneHotMatrix{UInt32, 0x00000002, Vector{UInt32}}, Nothing}, ArrayNode{OneHotArrays.OneHotMatrix{UInt32, 0x00000024, Vector{UInt32}}, Nothing}, ArrayNode{OneHotArrays.OneHotMatrix{UInt32, 0x00000024, Vector{UInt32}}, Nothing}}}, Nothing}, AlignedBags{Int64}, Nothing}, ArrayNode{OneHotArrays.OneHotMatrix{UInt32, 0x0000000a, Vector{UInt32}}, Nothing}, ArrayNode{OneHotArrays.OneHotMatrix{UInt32, 0x00000009, Vector{UInt32}}, Nothing}, ArrayNode{OneHotArrays.OneHotMatrix{UInt32, 0x00000007, Vector{UInt32}}, Nothing}, ArrayNode{OneHotArrays.OneHotMatrix{UInt32, 0x00000002, Vector{UInt32}}, Nothing}, ArrayNode{OneHotArrays.OneHotMatrix{UInt32, 0x0000000b, Vector{UInt32}}, Nothing}, ArrayNode{OneHotArrays.OneHotMatrix{UInt32, 0x0000000a, Vector{UInt32}}, Nothing}}}, Nothing}, AlignedBags{Int64}, Nothing}, ArrayNode{OneHotArrays.OneHotMatrix{UInt32, 0x0000002d, Vector{UInt32}}, Nothing}, ArrayNode{OneHotArrays.OneHotMatrix{UInt32, 0x00000025, Vector{UInt32}}, Nothing}, ArrayNode{OneHotArrays.OneHotMatrix{UInt32, 0x00000024, Vector{UInt32}}, Nothing}, ArrayNode{OneHotArrays.OneHotMatrix{UInt32, 0x00000003, Vector{UInt32}}, Nothing}, ArrayNode{OneHotArrays.OneHotMatrix{UInt32, 0x00000055, Vector{UInt32}}, Nothing}, ArrayNode{OneHotArrays.OneHotMatrix{UInt32, 0x0000002b, Vector{UInt32}}, Nothing}}}, Nothing}, AlignedBags{Int64}, Nothing}}}, itr::Base.Generator{Dict{Symbol, JsonGrinder.AbstractExtractor}, JsonGrinder.var"#114#115"{Bool, Dict{Symbol, Any}}}, offs::Int64, st::Int64)
#     @ Base .\array.jl:736
#  [43] collect_to_with_first!(dest::Vector{Pair{Symbol, BagNode{ProductNode{NamedTuple{(:children, :command_line, :process_name, :ppid, :track, :first_seen, :pid), Tuple{BagNode{ProductNode{NamedTuple{(:children, :command_line, :process_name, :ppid, :track, :first_seen, :pid), Tuple{BagNode{ProductNode{NamedTuple{(:children, :command_line, :process_name, :ppid, :track, :first_seen, :pid), Tuple{BagNode{ProductNode{NamedTuple{(:command_line, :process_name, :ppid, :track, :first_seen, :pid), Tuple{ArrayNode{OneHotArrays.OneHotMatrix{UInt32, 0x00000003, Vector{UInt32}}, Nothing}, ArrayNode{OneHotArrays.OneHotMatrix{UInt32, 0x00000003, Vector{UInt32}}, Nothing}, ArrayNode{OneHotArrays.OneHotMatrix{UInt32, 0x00000003, Vector{UInt32}}, Nothing}, ArrayNode{OneHotArrays.OneHotMatrix{UInt32, 0x00000002, Vector{UInt32}}, Nothing}, ArrayNode{OneHotArrays.OneHotMatrix{UInt32, 0x00000003, Vector{UInt32}}, Nothing}, ArrayNode{OneHotArrays.OneHotMatrix{UInt32, 0x00000003, Vector{UInt32}}, Nothing}}}, Nothing}, AlignedBags{Int64}, Nothing}, ArrayNode{OneHotArrays.OneHotMatrix{UInt32, 0x00000004, Vector{UInt32}}, Nothing}, ArrayNode{OneHotArrays.OneHotMatrix{UInt32, 0x00000004, Vector{UInt32}}, Nothing}, ArrayNode{OneHotArrays.OneHotMatrix{UInt32, 0x00000003, Vector{UInt32}}, Nothing}, ArrayNode{OneHotArrays.OneHotMatrix{UInt32, 0x00000002, Vector{UInt32}}, Nothing}, ArrayNode{OneHotArrays.OneHotMatrix{UInt32, 0x00000024, Vector{UInt32}}, Nothing}, ArrayNode{OneHotArrays.OneHotMatrix{UInt32, 0x00000024, Vector{UInt32}}, Nothing}}}, Nothing}, AlignedBags{Int64}, Nothing}, ArrayNode{OneHotArrays.OneHotMatrix{UInt32, 0x0000000a, Vector{UInt32}}, Nothing}, ArrayNode{OneHotArrays.OneHotMatrix{UInt32, 0x00000009, Vector{UInt32}}, Nothing}, ArrayNode{OneHotArrays.OneHotMatrix{UInt32, 0x00000007, Vector{UInt32}}, Nothing}, ArrayNode{OneHotArrays.OneHotMatrix{UInt32, 0x00000002, Vector{UInt32}}, Nothing}, ArrayNode{OneHotArrays.OneHotMatrix{UInt32, 0x0000000b, Vector{UInt32}}, Nothing}, ArrayNode{OneHotArrays.OneHotMatrix{UInt32, 0x0000000a, Vector{UInt32}}, Nothing}}}, Nothing}, AlignedBags{Int64}, Nothing}, ArrayNode{OneHotArrays.OneHotMatrix{UInt32, 0x0000002d, Vector{UInt32}}, Nothing}, ArrayNode{OneHotArrays.OneHotMatrix{UInt32, 0x00000025, Vector{UInt32}}, Nothing}, ArrayNode{OneHotArrays.OneHotMatrix{UInt32, 0x00000024, Vector{UInt32}}, Nothing}, ArrayNode{OneHotArrays.OneHotMatrix{UInt32, 0x00000003, Vector{UInt32}}, Nothing}, ArrayNode{OneHotArrays.OneHotMatrix{UInt32, 0x00000055, Vector{UInt32}}, Nothing}, ArrayNode{OneHotArrays.OneHotMatrix{UInt32, 0x0000002b, Vector{UInt32}}, Nothing}}}, Nothing}, AlignedBags{Int64}, Nothing}}}, v1::Pair{Symbol, BagNode{ProductNode{NamedTuple{(:children, :command_line, :process_name, :ppid, :track, :first_seen, :pid), Tuple{BagNode{ProductNode{NamedTuple{(:children, :command_line, :process_name, :ppid, :track, :first_seen, :pid), Tuple{BagNode{ProductNode{NamedTuple{(:children, :command_line, :process_name, :ppid, :track, :first_seen, :pid), Tuple{BagNode{ProductNode{NamedTuple{(:command_line, :process_name, :ppid, :track, :first_seen, :pid), Tuple{ArrayNode{OneHotArrays.OneHotMatrix{UInt32, 0x00000003, Vector{UInt32}}, Nothing}, ArrayNode{OneHotArrays.OneHotMatrix{UInt32, 0x00000003, Vector{UInt32}}, Nothing}, ArrayNode{OneHotArrays.OneHotMatrix{UInt32, 0x00000003, Vector{UInt32}}, Nothing}, ArrayNode{OneHotArrays.OneHotMatrix{UInt32, 0x00000002, Vector{UInt32}}, Nothing}, ArrayNode{OneHotArrays.OneHotMatrix{UInt32, 0x00000003, Vector{UInt32}}, Nothing}, ArrayNode{OneHotArrays.OneHotMatrix{UInt32, 0x00000003, Vector{UInt32}}, Nothing}}}, Nothing}, AlignedBags{Int64}, Nothing}, ArrayNode{OneHotArrays.OneHotMatrix{UInt32, 0x00000004, Vector{UInt32}}, Nothing}, ArrayNode{OneHotArrays.OneHotMatrix{UInt32, 0x00000004, Vector{UInt32}}, Nothing}, ArrayNode{OneHotArrays.OneHotMatrix{UInt32, 0x00000003, Vector{UInt32}}, Nothing}, ArrayNode{OneHotArrays.OneHotMatrix{UInt32, 0x00000002, Vector{UInt32}}, Nothing}, Arra ...
#     @ Base .\array.jl:706
#  [44] collect(itr::Base.Generator{Dict{Symbol, JsonGrinder.AbstractExtractor}, JsonGrinder.var"#114#115"{Bool, Dict{Symbol, Any}}})
#     @ Base .\array.jl:687
#  [45] (::ExtractDict{Dict{Symbol, JsonGrinder.AbstractExtractor}})(v::Dict{Symbol, Any}; store_input::Bool)
#     @ JsonGrinder C:\Users\aleca\.julia\packages\JsonGrinder\HGYbL\src\extractors\extractdict.jl:73
#  [46] (::ExtractDict{Dict{Symbol, JsonGrinder.AbstractExtractor}})(v::Dict{Symbol, Any})
#     @ JsonGrinder C:\Users\aleca\.julia\packages\JsonGrinder\HGYbL\src\extractors\extractdict.jl:73
#  [47] make_representative_sample(sch::JsonGrinder.DictEntry, ex::ExtractDict{Dict{Symbol, JsonGrinder.AbstractExtractor}})
#     @ JsonGrinder C:\Users\aleca\.julia\packages\JsonGrinder\HGYbL\src\schema\schema.jl:37
#  [48] reflectinmodel(::JsonGrinder.DictEntry, ::ExtractDict{Dict{Symbol, JsonGrinder.AbstractExtractor}}, ::Function, ::Vararg{Function, N} where N; kwargs::Base.Iterators.Pairs{Symbol, Dict{String, var"#11#14"}, Tuple{Symbol}, NamedTuple{(:fsm,), Tuple{Dict{String, var"#11#14"}}}})
#     @ JsonGrinder C:\Users\aleca\.julia\packages\JsonGrinder\HGYbL\src\schema\schema.jl:42
#  [49] top-level scope
#     @ In[11]:3
#  [50] eval
#     @ .\boot.jl:360 [inlined]

# %%
Flux.Optimise.train!(loss, ps, repeatedly(minibatch, iterations), opt, cb = Flux.throttle(cb, 2))
# Out:
# UndefVarError: minibatch not defined
#
# Stacktrace:
#  [1] top-level scope
#    @ In[12]:1
#  [2] eval
#    @ .\boot.jl:360 [inlined]
#  [3] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#    @ Base .\loading.jl:1116

# %% [markdown]
# # Accuracy and ROC curve

# %%
full_train_accuracy = calculate_accuracy(data[train_indexes], df_labels.label[train_indexes])
full_test_accuracy = calculate_accuracy(data[test_indexes], df_labels.label[test_indexes])
println("Final evaluation:")
println("Accuratcy on train data: $(full_train_accuracy)")
println("Accuratcy on test data: $(full_test_accuracy)")
# Out:
# UndefVarError: data not defined
#
# Stacktrace:
#  [1] top-level scope
#    @ In[13]:1
#  [2] eval
#    @ .\boot.jl:360 [inlined]
#  [3] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#    @ Base .\loading.jl:1116

# %%
using ROC: roc,AUC

scores=softmax(model(data[test_indexes]))[2,:]
roc_curve = roc(scores, df_labels.label[test_indexes], true);

println("AUC: $(AUC(roc_curve))")
plot(roc_curve,lw=2)
# Out:
# UndefVarError: data not defined
#
# Stacktrace:
#  [1] top-level scope
#    @ In[14]:3
#  [2] eval
#    @ .\boot.jl:360 [inlined]
#  [3] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#    @ Base .\loading.jl:1116
